# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join

# %% [markdown]
# #### Get names of csv's

# %% [markdown]
# Function Components

# %%
###Set up necessary variables

mypath='../raw_data/mozart_sonatas' #folder of pieces
metadata_filenames = ['documentation.txt','mps - pieces.csv'] #files we want to ignore for getting just indiv pieces
pieces_metadata_filepath = join(mypath,'mps - pieces.csv') #filepath for the pieces.csv file

# %%
movement_filenames = [f for f in listdir(mypath) if isfile(join(mypath, f))] 

#listdir gives list of files and directories at path end. if statement will check if its a file so we ignore dirs

# %%
for filename in metadata_filenames:
    if filename in movement_filenames:
        movement_filenames.remove(filename)

# %% [markdown]
# Combine into Function

# %%
def get_movement_filenames():
    mypath='../raw_data/mozart_sonatas' #folder of pieces
    metadata_filenames = ['documentation.txt','mps - pieces.csv'] #files we want to ignore for getting just indiv pieces
    
    movement_filenames = [filename for filename in listdir(mypath) if isfile(join(mypath, filename))] 
    #listdir gives list of files and directories at path end. if statement will check if its a file so we ignore dirs
    
    for filename in metadata_filenames:  #remove metadata filenames
        if filename in movement_filenames:    #make sure no error if already removed
            movement_filenames.remove(filename)
        
    return movement_filenames

# %% [markdown]
# Combine csv's

# %%
#make filenames and filepaths and piece names

movement_filenames = get_movement_filenames()
movement_filepaths = [join(mypath, filename) for filename in movement_filenames]
movement_names = [filename.split('mps - ')[1].split('.csv')[0] for filename in movement_filenames]

# %%
index = 10

movement_filenames[index],movement_filepaths[index],movement_names[index]
# Out:
# ('mps - K311-III.csv',
#  '../raw_data/mozart_sonatas/mps - K311-III.csv',
#  'K311-III')

# %%
#make dictionary of piece dfs
#loop over movement name and path, to make dict with movement name as key, and movement df as value

movement_df_dict = {name:pd.read_csv(path) for path, name in zip(movement_filepaths,movement_names)}

# %%
#pull each movement file into a df and into a list

movement_df_list = [pd.read_csv(path) for path in movement_filepaths]

# %%
#add movement name column to dfs [in dict]

for key in movement_df_dict:
    movement_df_dict[key]['movement_name'] = key

# %%
#add movement name column to dfs [in list]

for i in range(len(movement_df_list)):
    movement_df_list[i]['movement_name'] = movement_names[i]

# %%
movement_df_list[1]
# Out:
#    note_name  duration  measure  beat  subdiv harm  from_root  NCT  BI2  CI  \
# 0         d5         4        1     1       1    I          1    0    0   0
# 1          r         4        1     2       1    0          0    0    0   0
# 2         g4        16        1     3       1    I          4    1    0   0
# 3        f#4        16        1     3       2    I          3    0    0   0
# 4         e4        16        1     3       3    I          2    1    0   0
# 5         d4        16        1     3       4    I          1    0    0   0
# 6         g4        16        1     4       1    I          4    1    0   0
# 7        f#4        16        1     4       2    I          3    0    0   0
# 8         e4        16        1     4       3    I          2    1    0   0
# 9          d        16        1     4       4    I          1    0    0   0
# 10        a4         4        2     1       1    I          5    0    0   0
# 11       f#4         4        2     2       1    I          3    0    0   0
# 12        b4         4        2     3       1   vi          1    0    0   0
# 13         r         8        2     4       1    0          0    0    0   0
# 14       f#4         8        2     4       3   vi          5    0    0   1
# 15        g4         8        3     1       1   V7          7    0    0   1
# 16        e4         8        3     1       3   V7          5    0    0   1
# 17        a4         8        3     2       1    I          5    0    0   1
# 18       f#4         8        3     2       3    I          3    0    0   1
# 19        d4         8        3     3       1   vi          3    0    0   1
# 20        b3         8        3     3       3   vi          1    0    0   1
# 21        e4         8        3     4       1    V          5    0    0   1
# 22       c#4         8        3     4       3    V          3    0    0   1
# 23        a3         4        4     1       1    V          1    0    0   1
# 24         r         4        4     2       1    V          0    0    0   1
#
#     trill dynamic movement_name
# 0       0       f        K284-I
# 1       0       f        K284-I
# 2       0       f        K284-I
# 3       0       f        K284-I
# 4       0       f        K284-I
# 5       0       f        K284-I
# 6       0       f        K284-I
# 7       0       f        K284-I
# 8       0       f        K284-I
# 9       0       f        K284-I
# 10      0       f        K284-I
# 11      0       f        K284-I
# 12      0       f        K284-I
# 13      0       f        K284-I
# 14      0       f        K284-I
# 15      0       f        K284-I
# 16      0       f        K284-I
# 17      0       f        K284-I
# 18      0       f        K284-I
# 19      0       f        K284-I
# 20      0       f        K284-I
# 21      0       f        K284-I
# 22      0       f        K284-I
# 23      0       f        K284-I
# 24      0       f        K284-I

# %%
k
# Out:
# 'K284-III'

# %% [markdown]
# make conced df

# %%
stacked_movement_df = pd.concat(movement_df_list)

# %%
stacked_movement_df[stacked_movement_df.movement_name == 'K281-II']
# Out:
#    note_name duration  measure  beat subdiv  harm  from_root  NCT  BI2  CI  \
# 0          r        8        1     1      1     I          0    0    0   0
# 1        bb5        8        1     2      1     I          5    0    0   0
# 2        ab5        8        1     3      1     I          4    1    0   0
# 3         g5        8        2     1      1     I          3    0    0   0
# 4         f5        8        2     2      1     I          2    1    0   0
# 5        eb5        8        2     3      1     I          1    0    0   0
# 6         d5        8        3     1      1     I          7    1    0   0
# 7         c5        8        3     2      1     I          6    1    0   0
# 8        bb4        8        3     3      1     I          5    0    0   0
# 9        bb4        2        4     1      1    V6          1    0    0   0
# 10        c5        8        5     2      1  vi64          1    0    0   0
# 11        d5        8        5     3      1  vi64          2    1    0   0
# 12       eb5        4        6     1      1   vi6          3    0    0   1
# 13        c5        8        6     3      1    IV          3    0    0   1
# 14       bb4        4        7     1      1    V7          1    0    0   1
# 15       ab4       16        7     3      1    V7          7    0    0   1
# 16        g4       32        7     3      3    V7          6    1    0   1
# 17       ab4       32        7     3      4    V7          7    0    0   1
# 18        g4        8        8     1      1     I          3    0    0   1
#
#     trill dynamic movement_name
# 0       0       p       K281-II
# 1       0       p       K281-II
# 2       0       p       K281-II
# 3       0       c       K281-II
# 4       0       c       K281-II
# 5       0       c       K281-II
# 6       0       c       K281-II
# 7       0       c       K281-II
# 8       0       c       K281-II
# 9       0       f       K281-II
# 10      0       d       K281-II
# 11      0       d       K281-II
# 12      0       p       K281-II
# 13      0       p       K281-II
# 14      0       p       K281-II
# 15      1       p       K281-II
# 16      0       p       K281-II
# 17      0       p       K281-II
# 18      0       p       K281-II

# %%
stacked_movement_df[stacked_movement_df.duration == '5']
# Out:
#   note_name duration  measure  beat subdiv harm  from_root  NCT  BI2  CI  \
# 0       bb4        5        1     1      1    I          5    0    0   0
#
#    trill dynamic movement_name
# 0      0       p       K570-II

# %%
movement_df_dict['K570-II']
# Out:
#    note_name duration  measure  beat subdiv harm  from_root  NCT  BI2  CI  \
# 0        bb4        5        1     1      1    I          5    0    0   0
# 1         g4        8        1     2      1    I          3    0    0   0
# 2         f4        8        1     2      3    V          5    0    0   0
# 3        eb4        8        1     3      1    I          1    0    0   0
# 4        bb3        8        1     3      3    I          5    0    0   0
# 5        eb4        8        1     4      1    I          1    0    0   0
# 6         f4        8        1     4      3    V          5    0    0   0
# 7         g4        8        2     1      1    I          3    0    0   0
# 8        ab4        8        2     1      3  IV6          1    0    0   0
# 9        bb4        8        2     2      1   I6          5    0    0   0
# 10        c5        8        2     2      3   IV          3    0    0   0
# 11        g4       8d        2     3      1  I64          3    0    0   0
# 12       ab4       16        2     3      4  I64          4    1    0   0
# 13        f4       16        2     4      1    V          5    0    0   0
# 14        g4       16        2     4      2    V          6    1    0   0
# 15       ab4       16        2     4      3   V7          7    0    0   0
# 16        a4       16        2     4      4   V7          7    1    0   0
# 17       bb5        4        3     1      1   I6          5    0    1   0
# 18        g5        8        3     2      1    I          3    0    1   0
# 19        f5        8        3     2      3    V          5    0    1   0
# 20       eb5        8        3     3      1   I6          1    0    1   0
# 21        f5        8        3     3      3    V          5    0    1   0
# 22        g5        8        3     4      1    I          3    0    1   0
# 23       ab5        8        3     4      3  IV6          1    0    1   0
# 24       bb5        8        4     1      1   I6          5    0    1   0
# 25        b5       32        4     1      3  ii6          4    1    1   0
# 26        c6       32        4     1     3&  ii6          5    0    1   0
# 27       ab5       32        4     1      4  ii6          3    0    1   0
# 28        f5       32        4     1     4&  ii6          1    0    1   0
# 29       eb5        8        4     2      1  I64          1    0    1   0
# 30        g5       32        4     2      3   V7          6    1    1   0
# 31        f5       32        4     2     3&   V7          5    0    1   0
# 32        e5       32        4     2      4   V7          4    1    1   0
# 33        f5       32        4     2     4&   V7          5    0    1   0
# 34        f5        4        4     3      1    I          2    1    1   0
# 35       eb5        8        4     4      1    I          1    0    1   0
# 36         r        8        4     4      3    0          0    0    1   0
#
#     trill dynamic movement_name
# 0       0       p       K570-II
# 1       0       p       K570-II
# 2       0       p       K570-II
# 3       0       p       K570-II
# 4       0       p       K570-II
# 5       0       p       K570-II
# 6       0       p       K570-II
# 7       0       p       K570-II
# 8       0       p       K570-II
# 9       0       p       K570-II
# 10      0       p       K570-II
# 11      0       p       K570-II
# 12      0       p       K570-II
# 13      0       p       K570-II
# 14      0       p       K570-II
# 15      0       p       K570-II
# 16      0       p       K570-II
# 17      0       p       K570-II
# 18      0       p       K570-II
# 19      0       p       K570-II
# 20      0       p       K570-II
# 21      0       p       K570-II
# 22      0       p       K570-II
# 23      0       p       K570-II
# 24      0       p       K570-II
# 25      0       p       K570-II
# 26      0       p       K570-II
# 27      0       p       K570-II
# 28      0       p       K570-II
# 29      0       p       K570-II
# 30      0       p       K570-II
# 31      0       p       K570-II
# 32      0       p       K570-II
# 33      0       p       K570-II
# 34      0       p       K570-II
# 35      0       p       K570-II
# 36      0       p       K570-II

# %%
string.split('mps - ')[1].split('.csv')[0]
# Out:
# 'K281-II'
